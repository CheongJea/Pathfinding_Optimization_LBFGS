# %%
from Functions.potential_draw import draw_line_contour_graphs
import matplotlib.pyplot as plt
import numpy as np
import os

potential_2D_dir = "./2D_image/"
potential_3D_dir = "./3D_image/"
os.makedirs(potential_2D_dir, exist_ok=True)
os.makedirs(potential_3D_dir, exist_ok=True)


# ==============================
# 데이터 및 설정
# ==============================
obstacles = np.array([
    [-5, 20, 5, 10, 0, 7.5],
    [-5, 0, 0, 15, 0, 7.5],
    [15, 35, 20, 25, 30, 22.5],
    [30, 35, 0, 25, 30, 22.5]
], dtype=np.float32)

#obstacles = np.array([
#    [10,20,10,20,12,15]
# ])

margin = 2.0 

# 영역 지정
x = np.linspace(-10, 40, 150)
y = np.linspace(-10, 40, 150)

# 포텐셜 시각화
draw_line_contour_graphs(obstacles, lambda_obs=1.0, iter=10,x=x,y=y, margin=margin, potential_2D_dir=potential_2D_dir, potential_3D_dir=potential_3D_dir)
